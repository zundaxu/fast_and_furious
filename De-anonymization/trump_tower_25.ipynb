# %%
import pandas as pd

# %%
#df1 = pd.read_csv("yellow_tripdata_2014-11.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df2 = pd.read_csv("yellow_tripdata_2014-12.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df3 = pd.read_csv("yellow_tripdata_2015-01.csv")

# %%
#df4 = pd.read_csv("yellow_tripdata_2015-02.csv")

# %%
#df5 = pd.read_csv("yellow_tripdata_2015-03.csv")

# %%
#df6 = pd.read_csv("yellow_tripdata_2015-04.csv")

# %%
#df7 = pd.read_csv("yellow_tripdata_2015-07.csv")

# %%
df8 = pd.read_csv("yellow_tripdata_2015-08.csv")

# %%
df9 = pd.read_csv("yellow_tripdata_2015-09.csv")

# %%
df10 = pd.read_csv("yellow_tripdata_2015-10.csv")

# %%
df11 = pd.read_csv("yellow_tripdata_2015-11.csv")

# %%
df12 = pd.read_csv("yellow_tripdata_2015-12.csv")

# %%
df13 = pd.read_csv("yellow_tripdata_2016-01.csv")

# %%
df14 = pd.read_csv("yellow_tripdata_2016-02.csv")

# %%
df15 = pd.read_csv("yellow_tripdata_2016-03.csv")

# %%
df16 = pd.read_csv("yellow_tripdata_2016-04.csv")

# %%
df17 = pd.read_csv("yellow_tripdata_2016-05.csv")

# %%
df18 = pd.read_csv("yellow_tripdata_2016-06.csv")

# %%
df = df7

# %%
ki = df[(40.7635 <= df["pickup_latitude"]) & (df["pickup_latitude"] < 40.7645) \
   & (-73.9735 <= df["pickup_longitude"]) & (df["pickup_longitude"] < -73.9725)]

# %%
ki2 = ki[ki["tip_amount"] == 25.0]

# %%
ki2
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 3574069          1  2015-07-06 17:10:24   2015-07-06 17:24:17
# 7162390          1  2015-07-20 16:33:20   2015-07-20 16:48:24
# 7530407          1  2015-07-21 16:00:09   2015-07-21 16:30:48
# 10592655         1  2015-07-29 16:36:17   2015-07-29 16:57:09
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 3574069                 1            2.4        -73.973404        40.763901
# 7162390                 1            2.4        -73.973206        40.764191
# 7530407                 1            8.4        -73.973145        40.763721
# 10592655                2            2.3        -73.973419        40.764160
#
#           RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 3574069            1                  N         -73.999619         40.747524
# 7162390            1                  N         -74.000359         40.747631
# ...

# %%
rv = rv.append(ki2)

# %%
rv
# Out:
#              dropoff_datetime   dropoff_latitude   dropoff_longitude  \
# 1081642   2014-11-19 18:21:00          40.644667          -73.797453
# 3532731   2014-11-18 18:09:11          40.747615          -73.999942
# 5022524   2014-11-24 16:48:36          40.747844          -74.000472
# 11576027  2014-11-12 18:10:44          40.747607          -74.000648
# 11715068  2014-11-13 18:02:47          40.744087          -73.995233
# 885734    2014-12-30 18:03:57          40.746325          -74.001493
# 4258458   2014-12-17 17:40:04          40.744084          -73.995769
# 4331947   2014-12-17 19:04:39          40.719348          -74.041343
# 5511905   2014-12-22 18:07:09          40.744435          -73.995268
# 7991425   2014-12-08 17:10:11          40.747583          -74.000051
# 2643411                   NaN                NaN                 NaN
# 4497292                   NaN                NaN                 NaN
# 10007196                  NaN                NaN                 NaN
# ...

# %%
del df7
